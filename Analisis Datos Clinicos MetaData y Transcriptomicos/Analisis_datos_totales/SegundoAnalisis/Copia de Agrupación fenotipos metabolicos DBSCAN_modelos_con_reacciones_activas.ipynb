# %%
import os
import pandas as pd
from google.colab import drive

drive.mount('/content/drive')

# Ruta a la carpeta con archivos CSV en tu Drive
carpeta = '/content/drive/MyDrive/Modelos_actualizados2'

# Lista para guardar todos los flujos
todos_los_datos = []

for archivo in os.listdir(carpeta):
    if archivo.endswith('.csv'):
        ruta_archivo = os.path.join(carpeta, archivo)
        paciente_id = os.path.splitext(archivo)[0]

        # Leer el archivo CSV con encabezados 'Reaction' y 'Flux'
        df = pd.read_csv(ruta_archivo, sep=",", usecols=['Reaction', 'Flux'])

        # Agregar identificador de paciente
        df['paciente'] = paciente_id

        todos_los_datos.append(df)

# Combinar todos los DataFrames
df_completo = pd.concat(todos_los_datos, ignore_index=True)

# Guardar el archivo combinado
df_completo.to_csv('/content/drive/MyDrive/flujos_reacciones_unificados.csv', index=False)

print("✅ Archivo combinado guardado como 'flujos_reacciones_unificados.csv'")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Archivo combinado guardado como 'flujos_reacciones_unificados.csv'

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score
from sklearn.cluster import DBSCAN, KMeans
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# === 1. Cargar los datos ===
df_flujos = pd.read_csv('/content/drive/MyDrive/flujos_reacciones_unificados.csv')
df_flujos['Flux'] = pd.to_numeric(df_flujos['Flux'], errors='coerce')
df_flujos = df_flujos.dropna(subset=['Flux'])

# === 2. Pivotear ===
df_pivot = df_flujos.pivot_table(index='paciente', columns='Reaction', values='Flux')

# === 3. Imputar y escalar ===
imputer = SimpleImputer(strategy='mean')
X_imputed = imputer.fit_transform(df_pivot)

# === 4. PCA con más componentes ===
n_pca_components = 2  # Cambia este valor si quieres más o menos componentes
scaler_std = StandardScaler()
X_scaled_std = scaler_std.fit_transform(X_imputed)

pca = PCA(n_components=n_pca_components)
X_pca = pca.fit_transform(X_scaled_std)

# === 5. Varianza explicada acumulada ===
print("🔍 Varianza explicada acumulada (PCA):")
print(np.cumsum(pca.explained_variance_ratio_))

plt.figure(figsize=(8,4))
plt.plot(np.cumsum(pca.explained_variance_ratio_), marker='o')
plt.xlabel("Número de componentes PCA")
plt.ylabel("Varianza explicada acumulada")
plt.title("PCA: Varianza explicada")
plt.grid(True)
plt.tight_layout()
plt.show()

# === 6. DBSCAN sweep ===
results = []
print(f"=== DBSCAN sweep eps=0.1 a 20.0 (min_samples=1) usando PCA({n_pca_components}) ===")
for eps in np.arange(0.1, 20.1, 0.1):
    db = DBSCAN(eps=eps, min_samples=1)
    labels = db.fit_predict(X_pca)

    n_clusters = len(set(labels)) - (1 if -1 in labels else 0)
    n_noise = list(labels).count(-1)

    if 1 < n_clusters < len(X_pca):
        score = silhouette_score(X_pca, labels)
    else:
        score = -1

    results.append((eps, n_clusters, n_noise, score))

    if n_clusters > 1:
        print(f"eps={eps:.1f} | clusters={n_clusters:3d} | noise={n_noise:4d} | silhouette={score:.3f}")

# === 7. Mejor resultado DBSCAN ===
valid_results = [r for r in results if r[3] > 0]
if valid_results:
    best = max(valid_results, key=lambda x: x[3])
    print(f"\n🟢 Mejor eps: {best[0]:.2f} | Clusters: {best[1]} | Silhouette: {best[3]:.3f}")

    best_db = DBSCAN(eps=best[0], min_samples=1)
    best_labels = best_db.fit_predict(X_pca)

    df_dbscan = df_pivot.copy()
    df_dbscan['cluster'] = best_labels
    df_dbscan.to_csv('/content/drive/MyDrive/resultado_dbscan_eps20.csv')
    print("✅ Resultado DBSCAN guardado en 'resultado_dbscan_eps20.csv'")

    # Visualización
    plt.figure(figsize=(8, 4))
    eps_vals = [r[0] for r in valid_results]
    scores = [r[3] for r in valid_results]
    plt.plot(eps_vals, scores, marker='o')
    plt.axvline(best[0], color='red', linestyle='--', label=f'Mejor eps = {best[0]:.2f}')
    plt.xlabel('Epsilon')
    plt.ylabel('Silhouette Score')
    plt.title('DBSCAN: Silhouette vs Eps')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()
else:
    print("⚠️ DBSCAN aún no detecta múltiples clusters.")

# === 8. KMeans sweep ===
results_kmeans = []
print(f"\n=== KMeans sweep k=2 a 20 usando PCA({n_pca_components}) ===")
for k in range(2, 21):
    kmeans = KMeans(n_clusters=k, random_state=42, n_init='auto')
    labels = kmeans.fit_predict(X_pca)
    score = silhouette_score(X_pca, labels)
    results_kmeans.append((k, score))
    print(f"k={k:2d} | Silhouette Score={score:.3f}")

# === 9. Mejor resultado KMeans ===
best_k = max(results_kmeans, key=lambda x: x[1])
print(f"\n🟢 Mejor k = {best_k[0]} | Silhouette Score = {best_k[1]:.3f}")

# Guardar resultados
kmeans = KMeans(n_clusters=best_k[0], random_state=42, n_init='auto')
labels = kmeans.fit_predict(X_pca)

df_kmeans = df_pivot.copy()
df_kmeans['cluster'] = labels
df_kmeans.to_csv('/content/drive/MyDrive/resultado_kmeans.csv')
print("✅ Resultado K-Means guardado en 'resultado_kmeans.csv'")

# Visualización Silhouette KMeans
k_vals = [r[0] for r in results_kmeans]
scores = [r[1] for r in results_kmeans]

plt.figure(figsize=(8, 4))
plt.plot(k_vals, scores, marker='o')
plt.axvline(best_k[0], color='red', linestyle='--', label=f'Mejor k = {best_k[0]}')
plt.xlabel('Número de clusters (k)')
plt.ylabel('Silhouette Score')
plt.title('K-Means: Silhouette vs k')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Visualización 3D (solo primeras 3 componentes)
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_pca[:, 0], X_pca[:, 1], X_pca[:, 2], c=labels, cmap='tab10', s=50)
ax.set_title(f"K-Means clustering (k={best_k[0]}) sobre PCA({n_pca_components})")
plt.show()
# Out:
# 🔍 Varianza explicada acumulada (PCA):
# [0.07407018 0.10313314]
# === DBSCAN sweep eps=0.1 a 20.0 (min_samples=1) usando PCA(2) ===
# eps=0.1 | clusters= 60 | noise=   0 | silhouette=-1.000
# eps=0.2 | clusters= 60 | noise=   0 | silhouette=-1.000
# eps=0.3 | clusters= 60 | noise=   0 | silhouette=-1.000
# eps=0.4 | clusters= 59 | noise=   0 | silhouette=0.027
# eps=0.5 | clusters= 59 | noise=   0 | silhouette=0.027
# eps=0.6 | clusters= 59 | noise=   0 | silhouette=0.027
# eps=0.7 | clusters= 58 | noise=   0 | silhouette=0.051
# eps=0.8 | clusters= 58 | noise=   0 | silhouette=0.051
# eps=0.9 | clusters= 58 | noise=   0 | silhouette=0.051
# eps=1.0 | clusters= 57 | noise=   0 | silhouette=0.065
# eps=1.1 | clusters= 57 | noise=   0 | silhouette=0.065
# eps=1.2 | clusters= 57 | noise=   0 | silhouette=0.065
# eps=1.3 | clusters= 57 | noise=   0 | silhouette=0.065
# eps=1.4 | clusters= 56 | noise=   0 | silhouette=0.079
# eps=1.5 | clusters= 56 | noise=   0 | silhouette=0.079
# eps=1.6 | clusters= 56 | noise=   0 | silhouette=0.079
# eps=1.7 | clusters= 54 | noise=   0 | silhouette=0.090
# eps=1.8 | clusters= 54 | noise=   0 | silhouette=0.090
# eps=1.9 | clusters= 52 | noise=   0 | silhouette=0.129
# eps=2.0 | clusters= 50 | noise=   0 | silhouette=0.148
# eps=2.1 | clusters= 49 | noise=   0 | silhouette=0.154
# eps=2.2 | clusters= 45 | noise=   0 | silhouette=0.194
# eps=2.3 | clusters= 43 | noise=   0 | silhouette=0.209
# eps=2.4 | clusters= 39 | noise=   0 | silhouette=0.231
# eps=2.5 | clusters= 37 | noise=   0 | silhouette=0.267
# eps=2.6 | clusters= 35 | noise=   0 | silhouette=0.292
# eps=2.7 | clusters= 35 | noise=   0 | silhouette=0.292
# eps=2.8 | clusters= 33 | noise=   0 | silhouette=0.272
# eps=2.9 | clusters= 33 | noise=   0 | silhouette=0.272
# eps=3.0 | clusters= 33 | noise=   0 | silhouette=0.272
# eps=3.1 | clusters= 30 | noise=   0 | silhouette=0.286
# eps=3.2 | clusters= 28 | noise=   0 | silhouette=0.252
# eps=3.3 | clusters= 26 | noise=   0 | silhouette=0.270
# eps=3.4 | clusters= 25 | noise=   0 | silhouette=0.285
# eps=3.5 | clusters= 25 | noise=   0 | silhouette=0.285
# eps=3.6 | clusters= 25 | noise=   0 | silhouette=0.285
# eps=3.7 | clusters= 24 | noise=   0 | silhouette=0.302
# eps=3.8 | clusters= 22 | noise=   0 | silhouette=0.231
# eps=3.9 | clusters= 21 | noise=   0 | silhouette=0.266
# eps=4.0 | clusters= 20 | noise=   0 | silhouette=0.247
# eps=4.1 | clusters= 19 | noise=   0 | silhouette=0.226
# eps=4.2 | clusters= 19 | noise=   0 | silhouette=0.226
# eps=4.3 | clusters= 19 | noise=   0 | silhouette=0.226
# eps=4.4 | clusters= 18 | noise=   0 | silhouette=0.224
# eps=4.5 | clusters= 18 | noise=   0 | silhouette=0.224
# eps=4.6 | clusters= 18 | noise=   0 | silhouette=0.224
# eps=4.7 | clusters= 18 | noise=   0 | silhouette=0.224
# eps=4.8 | clusters= 18 | noise=   0 | silhouette=0.224
# eps=4.9 | clusters= 17 | noise=   0 | silhouette=0.190
# eps=5.0 | clusters= 16 | noise=   0 | silhouette=0.237
# eps=5.1 | clusters= 16 | noise=   0 | silhouette=0.237
# eps=5.2 | clusters= 13 | noise=   0 | silhouette=0.309
# eps=5.3 | clusters= 11 | noise=   0 | silhouette=0.252
# eps=5.4 | clusters= 10 | noise=   0 | silhouette=0.272
# eps=5.5 | clusters= 10 | noise=   0 | silhouette=0.272
# eps=5.6 | clusters= 10 | noise=   0 | silhouette=0.272
# eps=5.7 | clusters= 10 | noise=   0 | silhouette=0.272
# eps=5.8 | clusters=  9 | noise=   0 | silhouette=0.157
# eps=5.9 | clusters=  9 | noise=   0 | silhouette=0.157
# eps=6.0 | clusters=  8 | noise=   0 | silhouette=0.079
# eps=6.1 | clusters=  7 | noise=   0 | silhouette=0.086
# eps=6.2 | clusters=  7 | noise=   0 | silhouette=0.086
# eps=6.3 | clusters=  6 | noise=   0 | silhouette=-0.172
# eps=6.4 | clusters=  6 | noise=   0 | silhouette=-0.172
# eps=6.5 | clusters=  6 | noise=   0 | silhouette=-0.172
# eps=6.6 | clusters=  6 | noise=   0 | silhouette=-0.172
# eps=6.7 | clusters=  6 | noise=   0 | silhouette=-0.172
# eps=6.8 | clusters=  6 | noise=   0 | silhouette=-0.172
# eps=6.9 | clusters=  6 | noise=   0 | silhouette=-0.172
# eps=7.0 | clusters=  6 | noise=   0 | silhouette=-0.172
# eps=7.1 | clusters=  6 | noise=   0 | silhouette=-0.172
# eps=7.2 | clusters=  6 | noise=   0 | silhouette=-0.172
# eps=7.3 | clusters=  6 | noise=   0 | silhouette=-0.172
# eps=7.4 | clusters=  6 | noise=   0 | silhouette=-0.172
# eps=7.5 | clusters=  6 | noise=   0 | silhouette=-0.172
# eps=7.6 | clusters=  6 | noise=   0 | silhouette=-0.172
# eps=7.7 | clusters=  6 | noise=   0 | silhouette=-0.172
# eps=7.8 | clusters=  6 | noise=   0 | silhouette=-0.172
# eps=7.9 | clusters=  6 | noise=   0 | silhouette=-0.172
# eps=8.0 | clusters=  6 | noise=   0 | silhouette=-0.172
# eps=8.1 | clusters=  6 | noise=   0 | silhouette=-0.172
# eps=8.2 | clusters=  6 | noise=   0 | silhouette=-0.172
# eps=8.3 | clusters=  5 | noise=   0 | silhouette=-0.139
# eps=8.4 | clusters=  5 | noise=   0 | silhouette=-0.139
# eps=8.5 | clusters=  5 | noise=   0 | silhouette=-0.139
# eps=8.6 | clusters=  5 | noise=   0 | silhouette=-0.139
# eps=8.7 | clusters=  5 | noise=   0 | silhouette=-0.139
# eps=8.8 | clusters=  5 | noise=   0 | silhouette=-0.139
# eps=8.9 | clusters=  5 | noise=   0 | silhouette=-0.139
# eps=9.0 | clusters=  5 | noise=   0 | silhouette=-0.139
# eps=9.1 | clusters=  4 | noise=   0 | silhouette=-0.155
# eps=9.2 | clusters=  4 | noise=   0 | silhouette=-0.155
# eps=9.3 | clusters=  4 | noise=   0 | silhouette=-0.155
# eps=9.4 | clusters=  4 | noise=   0 | silhouette=-0.155
# eps=9.5 | clusters=  4 | noise=   0 | silhouette=-0.155
# eps=9.6 | clusters=  4 | noise=   0 | silhouette=-0.155
# eps=9.7 | clusters=  4 | noise=   0 | silhouette=-0.155
# eps=9.8 | clusters=  3 | noise=   0 | silhouette=0.219
# eps=9.9 | clusters=  3 | noise=   0 | silhouette=0.219
# eps=10.0 | clusters=  3 | noise=   0 | silhouette=0.219
# eps=10.1 | clusters=  3 | noise=   0 | silhouette=0.219
# eps=10.2 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=10.3 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=10.4 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=10.5 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=10.6 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=10.7 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=10.8 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=10.9 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=11.0 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=11.1 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=11.2 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=11.3 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=11.4 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=11.5 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=11.6 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=11.7 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=11.8 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=11.9 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=12.0 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=12.1 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=12.2 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=12.3 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=12.4 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=12.5 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=12.6 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=12.7 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=12.8 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=12.9 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=13.0 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=13.1 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=13.2 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=13.3 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=13.4 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=13.5 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=13.6 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=13.7 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=13.8 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=13.9 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=14.0 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=14.1 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=14.2 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=14.3 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=14.4 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=14.5 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=14.6 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=14.7 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=14.8 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=14.9 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=15.0 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=15.1 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=15.2 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=15.3 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=15.4 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=15.5 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=15.6 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=15.7 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=15.8 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=15.9 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=16.0 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=16.1 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=16.2 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=16.3 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=16.4 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=16.5 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=16.6 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=16.7 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=16.8 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=16.9 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=17.0 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=17.1 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=17.2 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=17.3 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=17.4 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=17.5 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=17.6 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=17.7 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=17.8 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=17.9 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=18.0 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=18.1 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=18.2 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=18.3 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=18.4 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=18.5 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=18.6 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=18.7 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=18.8 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=18.9 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=19.0 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=19.1 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=19.2 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=19.3 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=19.4 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=19.5 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=19.6 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=19.7 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=19.8 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=19.9 | clusters=  2 | noise=   0 | silhouette=0.738
# eps=20.0 | clusters=  2 | noise=   0 | silhouette=0.738
#
# 🟢 Mejor eps: 10.20 | Clusters: 2 | Silhouette: 0.738
# ✅ Resultado DBSCAN guardado en 'resultado_dbscan_eps20.csv'
# === KMeans sweep k=2 a 20 usando PCA(2) ===
# k= 2 | Silhouette Score=0.546
# k= 3 | Silhouette Score=0.575
# k= 4 | Silhouette Score=0.487
# k= 5 | Silhouette Score=0.424
# k= 6 | Silhouette Score=0.422
# k= 7 | Silhouette Score=0.414
# k= 8 | Silhouette Score=0.387
# k= 9 | Silhouette Score=0.393
# k=10 | Silhouette Score=0.392
# k=11 | Silhouette Score=0.384
# k=12 | Silhouette Score=0.398
# k=13 | Silhouette Score=0.389
# k=14 | Silhouette Score=0.396
# k=15 | Silhouette Score=0.390
# k=16 | Silhouette Score=0.406
# k=17 | Silhouette Score=0.395
# k=18 | Silhouette Score=0.376
# k=19 | Silhouette Score=0.366
# k=20 | Silhouette Score=0.359
#
# 🟢 Mejor k = 3 | Silhouette Score = 0.575
# ✅ Resultado K-Means guardado en 'resultado_kmeans.csv'
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-21-2976214937.py in <cell line: 0>()
#     133 fig = plt.figure(figsize=(8, 6))
#     134 ax = fig.add_subplot(111, projection='3d')
# --> 135 ax.scatter(X_pca[:, 0], X_pca[:, 1], X_pca[:, 2], c=labels, cmap='tab10', s=50)
#     136 ax.set_title(f"K-Means clustering (k={best_k[0]}) sobre PCA({n_pca_components})")
#     137 plt.show()
#
# IndexError: index 2 is out of bounds for axis 1 with size 2

# %%
from sklearn.cluster import KMeans

# Usamos los mismos datos escalados que arriba
kmeans = KMeans(n_clusters=3, random_state=42)  # Ajusta el número de clusters
labels = kmeans.fit_predict(X_scaled)

df_kmeans = df_pivot.copy()
df_kmeans['cluster'] = labels
df_kmeans.to_csv('/content/drive/MyDrive/resultado_kmeans.csv')
print("✅ Clustering K-Means guardado en 'resultado_kmeans.csv'")
# Out:
# ✅ Clustering K-Means guardado en 'resultado_kmeans.csv'

# %%
# === 2. Sweep de k ===
results = []
print("=== KMeans sweep k=2 a 20 ===")
for k in range(2, 21):
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(X_pca)
    score = silhouette_score(X_pca, labels)
    results.append((k, score))
    print(f"k={k:2d} | Silhouette Score={score:.3f}")

# === 3. Mejor k ===
best = max(results, key=lambda x: x[1])
print(f"\n🟢 Mejor k = {best[0]} | Silhouette Score = {best[1]:.3f}")

# === 4. Visualización del score ===
k_vals = [r[0] for r in results]
scores = [r[1] for r in results]

plt.figure(figsize=(8,4))
plt.plot(k_vals, scores, marker='o')
plt.axvline(best[0], color='red', linestyle='--', label=f'Mejor k = {best[0]}')
plt.xlabel('Número de clusters (k)')
plt.ylabel('Silhouette Score')
plt.title('K-Means: Silhouette vs k')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# === 5. Visualización en 3D ===
kmeans = KMeans(n_clusters=best[0], random_state=42)
labels = kmeans.fit_predict(X_pca)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_pca[:, 0], X_pca[:, 1], X_pca[:, 2], c=labels, cmap='tab10', s=50)
ax.set_title(f"K-Means clustering (k={best[0]})")
plt.show()
# Out:
# === KMeans sweep k=2 a 20 ===
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-13-3740859189.py in <cell line: 0>()
#       4 for k in range(2, 21):
#       5     kmeans = KMeans(n_clusters=k, random_state=42)
# ----> 6     labels = kmeans.fit_predict(X_pca)
#       7     score = silhouette_score(X_pca, labels)
#       8     results.append((k, score))
#
# NameError: name 'X_pca' is not defined
